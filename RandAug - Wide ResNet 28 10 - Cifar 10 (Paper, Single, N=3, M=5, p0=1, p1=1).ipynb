# %% [markdown]
# # RandAugment on Wide ResNet 28 10
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ## 1.1. Import

# %%
import augmentation, RandAugment, train
import torch, torchvision
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
N, M, p0, p1 = 3, 5, 1, 1

batch_size = 128
cifar_dir = '../../../../data/OCR/Jason/cifar10/'

transform_functions = ['Identity',
                       'AutoContrast', 'Brightness', 'Color', 'Contrast', 'Equalize', 'Posterize', 'Sharpness', 'Solarize', 
                       'Rotate', 'ShearX', 'ShearY', 'TranslateX', 'TranslateY']

# %%
pre_train_transform = [transforms.RandomCrop(32, padding=4), transforms.RandomHorizontalFlip()]
post_train_transform = [augmentation.Cutout(1, 8), transforms.ToTensor(), 
                        transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])]

train_transform = RandAugment.RandAug(N, M, p0, p1, pre_train_transform, post_train_transform, transform_functions)

test_transform = transforms.Compose([transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

train_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=True, download=False, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=False)

test_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=False, download=False, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=False)

# %% [markdown]
# # 3. Train Model

# %%
depth = 28
widen_factor = 10
dropout_rate = 0.3
num_classes = 10

gpu_id = 4
print_freq = 60
epoch_print = 10

save = False
epochs = 201

lr = 0.1
momentum = 0.9
weight_decay = 0.0005
nesterov = True
milestones = [60, 120, 160]

# %%
WRN_28_10 = train.Wide_ResNet(depth, widen_factor, dropout_rate, num_classes, gpu_id, print_freq, epoch_print)

# %%
WRN_28_10.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay, nesterov, milestones)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 1.9803, Test Loss : 2.1282, Train Acc : 30.4688, Test Acc : 24.3600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 1.9711, Test Loss : 1.7852, Train Acc : 23.4375, Test Acc : 35.0200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 1.6943, Test Loss : 1.7931, Train Acc : 39.8438, Test Acc : 35.0800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 1.6484, Test Loss : 1.5589, Train Acc : 35.9375, Test Acc : 43.0100
# Iteration : 300 - Train Loss : 1.6710, Test Loss : 2.0684, Train Acc : 36.7188, Test Acc : 38.7800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 1.5235, Test Loss : 1.7091, Train Acc : 42.9688, Test Acc : 44.1300
# Epoch 11 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.7827, Test Loss : 0.6120, Train Acc : 71.8750, Test Acc : 78.6500
# Iteration : 120 - Train Loss : 0.6780, Test Loss : 0.7377, Train Acc : 76.5625, Test Acc : 76.4300
# Iteration : 180 - Train Loss : 0.7432, Test Loss : 0.7731, Train Acc : 71.8750, Test Acc : 74.1400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.7202, Test Loss : 0.5724, Train Acc : 75.7812, Test Acc : 81.0900
# Iteration : 300 - Train Loss : 0.6712, Test Loss : 0.5820, Train Acc : 76.5625, Test Acc : 80.5100
# Iteration : 360 - Train Loss : 0.7275, Test Loss : 0.6949, Train Acc : 71.8750, Test Acc : 76.3600
# Epoch 21 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.6223, Test Loss : 0.4685, Train Acc : 78.1250, Test Acc : 84.6600
# Iteration : 120 - Train Loss : 0.7225, Test Loss : 0.5554, Train Acc : 74.2188, Test Acc : 81.8500
# Iteration : 180 - Train Loss : 0.5837, Test Loss : 0.5344, Train Acc : 81.2500, Test Acc : 81.9600
# Iteration : 240 - Train Loss : 0.6724, Test Loss : 0.5247, Train Acc : 76.5625, Test Acc : 82.6200
# Iteration : 300 - Train Loss : 0.6670, Test Loss : 0.5163, Train Acc : 75.0000, Test Acc : 82.8800
# Iteration : 360 - Train Loss : 0.4829, Test Loss : 0.6592, Train Acc : 82.0312, Test Acc : 79.3600
# Epoch 31 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.4751, Test Loss : 0.4614, Train Acc : 82.8125, Test Acc : 85.0000
# Iteration : 120 - Train Loss : 0.4321, Test Loss : 0.5120, Train Acc : 87.5000, Test Acc : 82.9700
# Iteration : 180 - Train Loss : 0.7517, Test Loss : 0.4876, Train Acc : 75.7812, Test Acc : 84.4500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.7954, Test Loss : 0.4405, Train Acc : 71.0938, Test Acc : 85.1400
# Iteration : 300 - Train Loss : 0.5563, Test Loss : 0.5143, Train Acc : 81.2500, Test Acc : 83.5400
# Iteration : 360 - Train Loss : 0.5747, Test Loss : 0.5583, Train Acc : 81.2500, Test Acc : 82.4100
# Epoch 41 Started...
# Iteration : 60 - Train Loss : 0.5684, Test Loss : 0.4583, Train Acc : 82.8125, Test Acc : 85.0600
# Iteration : 120 - Train Loss : 0.5346, Test Loss : 0.4865, Train Acc : 81.2500, Test Acc : 83.9500
# Iteration : 180 - Train Loss : 0.6657, Test Loss : 0.5012, Train Acc : 78.1250, Test Acc : 83.0800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.5863, Test Loss : 0.4597, Train Acc : 81.2500, Test Acc : 85.4200
# Iteration : 300 - Train Loss : 0.6475, Test Loss : 0.4584, Train Acc : 78.1250, Test Acc : 84.8700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.5581, Test Loss : 0.4198, Train Acc : 81.2500, Test Acc : 86.3600
# Epoch 51 Started...
# Iteration : 60 - Train Loss : 0.6246, Test Loss : 0.6077, Train Acc : 79.6875, Test Acc : 80.9300
# Iteration : 120 - Train Loss : 0.6951, Test Loss : 0.5231, Train Acc : 76.5625, Test Acc : 83.2700
# Iteration : 180 - Train Loss : 0.6313, Test Loss : 0.4466, Train Acc : 80.4688, Test Acc : 85.3200
# Iteration : 240 - Train Loss : 0.6086, Test Loss : 0.5946, Train Acc : 78.1250, Test Acc : 80.9500
# Iteration : 300 - Train Loss : 0.6936, Test Loss : 0.4758, Train Acc : 81.2500, Test Acc : 84.5000
# Iteration : 360 - Train Loss : 0.3801, Test Loss : 0.4709, Train Acc : 85.9375, Test Acc : 85.4200
# Epoch 61 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.3556, Test Loss : 0.2473, Train Acc : 89.0625, Test Acc : 91.4900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.4235, Test Loss : 0.2314, Train Acc : 84.3750, Test Acc : 91.7800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.2920, Test Loss : 0.2230, Train Acc : 90.6250, Test Acc : 92.2900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.3353, Test Loss : 0.2100, Train Acc : 88.2812, Test Acc : 92.5100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.2604, Test Loss : 0.2066, Train Acc : 91.4062, Test Acc : 92.8400
# Iteration : 360 - Train Loss : 0.3390, Test Loss : 0.2114, Train Acc : 86.7188, Test Acc : 92.7900
# Epoch 71 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.2355, Test Loss : 0.1841, Train Acc : 94.5312, Test Acc : 93.9300
# Iteration : 120 - Train Loss : 0.3589, Test Loss : 0.2423, Train Acc : 90.6250, Test Acc : 92.0700
# Iteration : 180 - Train Loss : 0.2931, Test Loss : 0.1942, Train Acc : 92.1875, Test Acc : 93.5200
# Iteration : 240 - Train Loss : 0.3328, Test Loss : 0.1842, Train Acc : 87.5000, Test Acc : 93.7300
# Iteration : 300 - Train Loss : 0.3614, Test Loss : 0.2200, Train Acc : 90.6250, Test Acc : 92.6400
# Iteration : 360 - Train Loss : 0.3560, Test Loss : 0.2490, Train Acc : 86.7188, Test Acc : 91.8200
# Epoch 81 Started...
# Iteration : 60 - Train Loss : 0.2749, Test Loss : 0.2154, Train Acc : 89.8438, Test Acc : 92.6200
# Iteration : 120 - Train Loss : 0.3506, Test Loss : 0.2007, Train Acc : 86.7188, Test Acc : 93.4600
# Iteration : 180 - Train Loss : 0.3207, Test Loss : 0.2107, Train Acc : 89.0625, Test Acc : 92.9600
# Iteration : 240 - Train Loss : 0.2621, Test Loss : 0.2004, Train Acc : 91.4062, Test Acc : 93.1800
# Iteration : 300 - Train Loss : 0.2856, Test Loss : 0.2142, Train Acc : 89.8438, Test Acc : 93.0300
# Iteration : 360 - Train Loss : 0.2215, Test Loss : 0.2454, Train Acc : 93.7500, Test Acc : 92.0800
# Epoch 91 Started...
# Iteration : 60 - Train Loss : 0.3053, Test Loss : 0.2181, Train Acc : 92.1875, Test Acc : 92.7900
# Iteration : 120 - Train Loss : 0.3584, Test Loss : 0.2443, Train Acc : 89.0625, Test Acc : 92.0700
# Iteration : 180 - Train Loss : 0.3458, Test Loss : 0.2002, Train Acc : 90.6250, Test Acc : 93.3300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.2950, Test Loss : 0.1738, Train Acc : 86.7188, Test Acc : 94.2300
# Iteration : 300 - Train Loss : 0.2500, Test Loss : 0.2224, Train Acc : 92.1875, Test Acc : 92.8000
# Iteration : 360 - Train Loss : 0.3508, Test Loss : 0.2075, Train Acc : 84.3750, Test Acc : 93.2800
# Epoch 101 Started...
# Iteration : 60 - Train Loss : 0.2287, Test Loss : 0.2378, Train Acc : 92.9688, Test Acc : 92.2800
# Iteration : 120 - Train Loss : 0.2527, Test Loss : 0.2321, Train Acc : 87.5000, Test Acc : 92.5800
# Iteration : 180 - Train Loss : 0.3453, Test Loss : 0.1874, Train Acc : 89.0625, Test Acc : 93.7400
# Iteration : 240 - Train Loss : 0.2426, Test Loss : 0.2527, Train Acc : 89.8438, Test Acc : 92.2800
# Iteration : 300 - Train Loss : 0.2454, Test Loss : 0.2175, Train Acc : 91.4062, Test Acc : 93.2100
# Iteration : 360 - Train Loss : 0.3042, Test Loss : 0.2222, Train Acc : 92.1875, Test Acc : 93.3500
# Epoch 111 Started...
# Iteration : 60 - Train Loss : 0.2773, Test Loss : 0.1758, Train Acc : 91.4062, Test Acc : 93.7700
# Iteration : 120 - Train Loss : 0.1865, Test Loss : 0.2077, Train Acc : 94.5312, Test Acc : 93.2600
# Iteration : 180 - Train Loss : 0.5351, Test Loss : 0.2288, Train Acc : 80.4688, Test Acc : 92.3300
# Iteration : 240 - Train Loss : 0.3438, Test Loss : 0.2096, Train Acc : 89.8438, Test Acc : 93.1900
# Iteration : 300 - Train Loss : 0.2262, Test Loss : 0.1977, Train Acc : 89.0625, Test Acc : 93.4300
# Iteration : 360 - Train Loss : 0.2736, Test Loss : 0.2021, Train Acc : 91.4062, Test Acc : 93.3200
# Epoch 121 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.1397, Test Loss : 0.1364, Train Acc : 95.3125, Test Acc : 95.4400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.1082, Test Loss : 0.1317, Train Acc : 97.6562, Test Acc : 95.5000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.1901, Test Loss : 0.1245, Train Acc : 95.3125, Test Acc : 95.7400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.2703, Test Loss : 0.1243, Train Acc : 92.1875, Test Acc : 95.9400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.1711, Test Loss : 0.1191, Train Acc : 93.7500, Test Acc : 96.0300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.2390, Test Loss : 0.1189, Train Acc : 92.1875, Test Acc : 96.1500
# Epoch 131 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0530, Test Loss : 0.1205, Train Acc : 99.2188, Test Acc : 96.3300
# Iteration : 120 - Train Loss : 0.1822, Test Loss : 0.1227, Train Acc : 92.9688, Test Acc : 96.2500
# Iteration : 180 - Train Loss : 0.0893, Test Loss : 0.1195, Train Acc : 96.8750, Test Acc : 96.3300
# Iteration : 240 - Train Loss : 0.0969, Test Loss : 0.1251, Train Acc : 97.6562, Test Acc : 96.1300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.1582, Test Loss : 0.1186, Train Acc : 92.9688, Test Acc : 96.4900
# Iteration : 360 - Train Loss : 0.0664, Test Loss : 0.1227, Train Acc : 98.4375, Test Acc : 96.4400
# Epoch 141 Started...
# Iteration : 60 - Train Loss : 0.1358, Test Loss : 0.1174, Train Acc : 94.5312, Test Acc : 96.3900
# Iteration : 120 - Train Loss : 0.0748, Test Loss : 0.1218, Train Acc : 97.6562, Test Acc : 96.3800
# Iteration : 180 - Train Loss : 0.1119, Test Loss : 0.1132, Train Acc : 95.3125, Test Acc : 96.4400
# Iteration : 240 - Train Loss : 0.1224, Test Loss : 0.1199, Train Acc : 94.5312, Test Acc : 96.3800
# Iteration : 300 - Train Loss : 0.1431, Test Loss : 0.1177, Train Acc : 96.0938, Test Acc : 96.4000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.1862, Test Loss : 0.1168, Train Acc : 93.7500, Test Acc : 96.5000
# Epoch 151 Started...
# Iteration : 60 - Train Loss : 0.1496, Test Loss : 0.1216, Train Acc : 95.3125, Test Acc : 96.4400
# Iteration : 120 - Train Loss : 0.1442, Test Loss : 0.1263, Train Acc : 95.3125, Test Acc : 96.4000
# Iteration : 180 - Train Loss : 0.1561, Test Loss : 0.1309, Train Acc : 96.0938, Test Acc : 96.3600
# Iteration : 240 - Train Loss : 0.2347, Test Loss : 0.1247, Train Acc : 92.9688, Test Acc : 96.4500
# Iteration : 300 - Train Loss : 0.0695, Test Loss : 0.1218, Train Acc : 99.2188, Test Acc : 96.4100
# Iteration : 360 - Train Loss : 0.1001, Test Loss : 0.1235, Train Acc : 96.0938, Test Acc : 96.4800
# Epoch 161 Started...
# Iteration : 60 - Train Loss : 0.0793, Test Loss : 0.1238, Train Acc : 97.6562, Test Acc : 96.4100
# Iteration : 120 - Train Loss : 0.1414, Test Loss : 0.1217, Train Acc : 93.7500, Test Acc : 96.4700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.0407, Test Loss : 0.1191, Train Acc : 98.4375, Test Acc : 96.5400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.0513, Test Loss : 0.1185, Train Acc : 98.4375, Test Acc : 96.6500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.0825, Test Loss : 0.1170, Train Acc : 96.8750, Test Acc : 96.6900
# Iteration : 360 - Train Loss : 0.0974, Test Loss : 0.1133, Train Acc : 96.8750, Test Acc : 96.6100
# Epoch 171 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.1332, Test Loss : 0.1081, Train Acc : 95.3125, Test Acc : 96.9400
# Iteration : 120 - Train Loss : 0.0623, Test Loss : 0.1102, Train Acc : 97.6562, Test Acc : 96.7700
# Iteration : 180 - Train Loss : 0.1133, Test Loss : 0.1087, Train Acc : 95.3125, Test Acc : 96.9000
# Iteration : 240 - Train Loss : 0.0966, Test Loss : 0.1095, Train Acc : 96.0938, Test Acc : 96.7800
# Iteration : 300 - Train Loss : 0.0960, Test Loss : 0.1099, Train Acc : 96.8750, Test Acc : 96.9100
# Iteration : 360 - Train Loss : 0.0584, Test Loss : 0.1085, Train Acc : 97.6562, Test Acc : 96.9300
# Epoch 181 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0566, Test Loss : 0.1095, Train Acc : 98.4375, Test Acc : 97.0700
# Iteration : 120 - Train Loss : 0.1194, Test Loss : 0.1111, Train Acc : 96.0938, Test Acc : 96.9400
# Iteration : 180 - Train Loss : 0.0391, Test Loss : 0.1080, Train Acc : 99.2188, Test Acc : 96.9600
# Iteration : 240 - Train Loss : 0.0550, Test Loss : 0.1080, Train Acc : 98.4375, Test Acc : 97.0700
# Iteration : 300 - Train Loss : 0.0344, Test Loss : 0.1075, Train Acc : 100.0000, Test Acc : 97.0700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.0429, Test Loss : 0.1080, Train Acc : 98.4375, Test Acc : 97.1100
# Epoch 191 Started...
# Iteration : 60 - Train Loss : 0.0618, Test Loss : 0.1104, Train Acc : 98.4375, Test Acc : 96.8800
# Iteration : 120 - Train Loss : 0.0261, Test Loss : 0.1100, Train Acc : 99.2188, Test Acc : 97.0400
# Iteration : 180 - Train Loss : 0.0438, Test Loss : 0.1103, Train Acc : 98.4375, Test Acc : 96.9800
# Iteration : 240 - Train Loss : 0.0627, Test Loss : 0.1105, Train Acc : 97.6562, Test Acc : 97.0300
# Iteration : 300 - Train Loss : 0.0143, Test Loss : 0.1103, Train Acc : 100.0000, Test Acc : 97.0700
# Iteration : 360 - Train Loss : 0.0485, Test Loss : 0.1145, Train Acc : 98.4375, Test Acc : 96.9200
# Epoch 201 Started...
# Iteration : 60 - Train Loss : 0.0801, Test Loss : 0.1156, Train Acc : 95.3125, Test Acc : 96.9100
# Iteration : 120 - Train Loss : 0.0588, Test Loss : 0.1118, Train Acc : 97.6562, Test Acc : 96.9600
# Iteration : 180 - Train Loss : 0.0315, Test Loss : 0.1115, Train Acc : 99.2188, Test Acc : 96.8300
# Iteration : 240 - Train Loss : 0.0627, Test Loss : 0.1138, Train Acc : 97.6562, Test Acc : 97.0000
# Iteration : 300 - Train Loss : 0.0686, Test Loss : 0.1123, Train Acc : 98.4375, Test Acc : 97.0000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.0404, Test Loss : 0.1104, Train Acc : 98.4375, Test Acc : 97.1200

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(WRN_28_10.train_losses, label='Train')
test_lossline, = plt.plot(WRN_28_10.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(WRN_28_10.train_acc, label='Train')
test_accline, = plt.plot(WRN_28_10.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')
