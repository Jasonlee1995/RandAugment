# %% [markdown]
# # RandAugment on Wide ResNet 28 10
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ## 1.1. Import

# %%
import augmentation, RandAugment, train
import torch, torchvision
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
N, M, p0, p1 = 3, 5, 1, 1

batch_size = 128
cifar_dir = '../../../../data/OCR/Jason/cifar10/'

transform_functions = ['AutoContrast', 'Brightness', 'Color', 'Contrast', 'Equalize', 'Invert', 'Posterize', 
                       'Sharpness', 'Solarize', 'SolarizeAdd', 'Cutout', 'Rotate', 'ShearX', 'ShearY', 'TranslateX', 'TranslateY']

# %%
pre_train_transform = [transforms.RandomCrop(32, padding=4), transforms.RandomHorizontalFlip()]
post_train_transform = [augmentation.Cutout(1, 8), transforms.ToTensor(), 
                        transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])]

train_transform = RandAugment.RandAug(N, M, p0, p1, pre_train_transform, post_train_transform, transform_functions)

test_transform = transforms.Compose([transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

train_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=True, download=False, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=False)

test_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=False, download=False, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=False)

# %% [markdown]
# # 3. Train Model

# %%
depth = 28
widen_factor = 10
dropout_rate = 0.3
num_classes = 10

gpu_id = 4
print_freq = 60
epoch_print = 10

save = False
epochs = 201

lr = 0.1
momentum = 0.9
weight_decay = 0.0005
nesterov = True
milestones = [60, 120, 160]

# %%
WRN_28_10 = train.Wide_ResNet(depth, widen_factor, dropout_rate, num_classes, gpu_id, print_freq, epoch_print)

# %%
WRN_28_10.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay, nesterov, milestones)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 2.1225, Test Loss : 2.2348, Train Acc : 19.5312, Test Acc : 19.1200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 2.0492, Test Loss : 2.6537, Train Acc : 20.3125, Test Acc : 19.9300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 1.8577, Test Loss : 2.1780, Train Acc : 31.2500, Test Acc : 30.8500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 1.8201, Test Loss : 1.7929, Train Acc : 35.1562, Test Acc : 36.4600
# Iteration : 300 - Train Loss : 1.7520, Test Loss : 2.0334, Train Acc : 39.0625, Test Acc : 34.2000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 1.6668, Test Loss : 1.3903, Train Acc : 34.3750, Test Acc : 49.9600
# Epoch 11 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.6802, Test Loss : 0.5698, Train Acc : 78.1250, Test Acc : 80.3600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.8336, Test Loss : 0.5717, Train Acc : 69.5312, Test Acc : 80.6500
# Iteration : 180 - Train Loss : 0.8703, Test Loss : 0.6825, Train Acc : 68.7500, Test Acc : 77.3500
# Iteration : 240 - Train Loss : 0.7466, Test Loss : 0.6222, Train Acc : 77.3438, Test Acc : 79.2800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.9298, Test Loss : 0.5582, Train Acc : 71.0938, Test Acc : 81.1600
# Iteration : 360 - Train Loss : 0.7519, Test Loss : 0.6604, Train Acc : 76.5625, Test Acc : 77.6400
# Epoch 21 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.5855, Test Loss : 0.5459, Train Acc : 78.9062, Test Acc : 82.2000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.8348, Test Loss : 0.5223, Train Acc : 72.6562, Test Acc : 82.7500
# Iteration : 180 - Train Loss : 0.6836, Test Loss : 0.8901, Train Acc : 80.4688, Test Acc : 72.8400
# Iteration : 240 - Train Loss : 0.6462, Test Loss : 0.5484, Train Acc : 77.3438, Test Acc : 81.3300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.7325, Test Loss : 0.4554, Train Acc : 69.5312, Test Acc : 84.0700
# Iteration : 360 - Train Loss : 0.6538, Test Loss : 0.6037, Train Acc : 78.9062, Test Acc : 79.9900
# Epoch 31 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.6695, Test Loss : 0.4838, Train Acc : 75.7812, Test Acc : 84.4700
# Iteration : 120 - Train Loss : 0.6577, Test Loss : 0.5409, Train Acc : 73.4375, Test Acc : 82.1400
# Iteration : 180 - Train Loss : 0.7972, Test Loss : 0.4740, Train Acc : 75.0000, Test Acc : 84.3400
# Iteration : 240 - Train Loss : 0.6071, Test Loss : 0.5004, Train Acc : 75.0000, Test Acc : 83.4400
# Iteration : 300 - Train Loss : 0.5469, Test Loss : 0.5959, Train Acc : 79.6875, Test Acc : 79.8400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.8858, Test Loss : 0.4215, Train Acc : 71.8750, Test Acc : 85.9800
# Epoch 41 Started...
# Iteration : 60 - Train Loss : 0.7762, Test Loss : 0.4341, Train Acc : 75.7812, Test Acc : 85.3800
# Iteration : 120 - Train Loss : 0.6041, Test Loss : 0.4670, Train Acc : 78.9062, Test Acc : 83.8900
# Iteration : 180 - Train Loss : 0.6042, Test Loss : 0.4205, Train Acc : 78.9062, Test Acc : 85.4800
# Iteration : 240 - Train Loss : 0.6665, Test Loss : 0.7942, Train Acc : 79.6875, Test Acc : 75.8800
# Iteration : 300 - Train Loss : 0.6273, Test Loss : 0.4248, Train Acc : 75.7812, Test Acc : 85.8000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.6029, Test Loss : 0.3959, Train Acc : 80.4688, Test Acc : 86.2700
# Epoch 51 Started...
# Iteration : 60 - Train Loss : 0.4637, Test Loss : 0.4951, Train Acc : 82.0312, Test Acc : 83.3700
# Iteration : 120 - Train Loss : 0.7007, Test Loss : 0.4156, Train Acc : 77.3438, Test Acc : 86.0400
# Iteration : 180 - Train Loss : 0.6079, Test Loss : 0.5592, Train Acc : 79.6875, Test Acc : 81.5900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.6071, Test Loss : 0.4000, Train Acc : 75.0000, Test Acc : 86.3800
# Iteration : 300 - Train Loss : 0.5330, Test Loss : 0.4882, Train Acc : 81.2500, Test Acc : 83.3800
# Iteration : 360 - Train Loss : 0.5433, Test Loss : 0.5305, Train Acc : 78.9062, Test Acc : 83.0200
# Epoch 61 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.5008, Test Loss : 0.2527, Train Acc : 82.0312, Test Acc : 91.2200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.3839, Test Loss : 0.2363, Train Acc : 87.5000, Test Acc : 91.9600
# Iteration : 180 - Train Loss : 0.4750, Test Loss : 0.2301, Train Acc : 85.9375, Test Acc : 91.9400
# Iteration : 240 - Train Loss : 0.6025, Test Loss : 0.2417, Train Acc : 78.1250, Test Acc : 91.7900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.3770, Test Loss : 0.2295, Train Acc : 87.5000, Test Acc : 91.9800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.4599, Test Loss : 0.2106, Train Acc : 86.7188, Test Acc : 92.6700
# Epoch 71 Started...
# Iteration : 60 - Train Loss : 0.3052, Test Loss : 0.2125, Train Acc : 89.8438, Test Acc : 92.6500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.3050, Test Loss : 0.1984, Train Acc : 89.0625, Test Acc : 93.2500
# Iteration : 180 - Train Loss : 0.3422, Test Loss : 0.2044, Train Acc : 91.4062, Test Acc : 93.0200
# Iteration : 240 - Train Loss : 0.3272, Test Loss : 0.2090, Train Acc : 85.1562, Test Acc : 92.9400
# Iteration : 300 - Train Loss : 0.4579, Test Loss : 0.2364, Train Acc : 87.5000, Test Acc : 92.1400
# Iteration : 360 - Train Loss : 0.3444, Test Loss : 0.2250, Train Acc : 89.0625, Test Acc : 92.5300
# Epoch 81 Started...
# Iteration : 60 - Train Loss : 0.3361, Test Loss : 0.2063, Train Acc : 87.5000, Test Acc : 93.1600
# Iteration : 120 - Train Loss : 0.2661, Test Loss : 0.2678, Train Acc : 92.1875, Test Acc : 91.2300
# Iteration : 180 - Train Loss : 0.4008, Test Loss : 0.2100, Train Acc : 86.7188, Test Acc : 92.7000
# Iteration : 240 - Train Loss : 0.4200, Test Loss : 0.2087, Train Acc : 86.7188, Test Acc : 92.8100
# Iteration : 300 - Train Loss : 0.3759, Test Loss : 0.2184, Train Acc : 86.7188, Test Acc : 92.5800
# Iteration : 360 - Train Loss : 0.3165, Test Loss : 0.2206, Train Acc : 86.7188, Test Acc : 92.4200
# Epoch 91 Started...
# Iteration : 60 - Train Loss : 0.4523, Test Loss : 0.2403, Train Acc : 85.1562, Test Acc : 92.0200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.3944, Test Loss : 0.1967, Train Acc : 89.0625, Test Acc : 93.4100
# Iteration : 180 - Train Loss : 0.2300, Test Loss : 0.2371, Train Acc : 89.8438, Test Acc : 92.3100
# Iteration : 240 - Train Loss : 0.4085, Test Loss : 0.2085, Train Acc : 85.9375, Test Acc : 93.1300
# Iteration : 300 - Train Loss : 0.4658, Test Loss : 0.2217, Train Acc : 82.8125, Test Acc : 93.0600
# Iteration : 360 - Train Loss : 0.3165, Test Loss : 0.2078, Train Acc : 89.0625, Test Acc : 92.9400
# Epoch 101 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.4907, Test Loss : 0.1943, Train Acc : 82.8125, Test Acc : 93.6200
# Iteration : 120 - Train Loss : 0.3855, Test Loss : 0.2354, Train Acc : 89.0625, Test Acc : 92.5300
# Iteration : 180 - Train Loss : 0.2771, Test Loss : 0.2242, Train Acc : 89.0625, Test Acc : 92.5100
# Iteration : 240 - Train Loss : 0.2838, Test Loss : 0.2043, Train Acc : 88.2812, Test Acc : 93.1600
# Iteration : 300 - Train Loss : 0.2381, Test Loss : 0.2742, Train Acc : 93.7500, Test Acc : 91.1100
# Iteration : 360 - Train Loss : 0.4814, Test Loss : 0.2483, Train Acc : 86.7188, Test Acc : 92.0200
# Epoch 111 Started...
# Iteration : 60 - Train Loss : 0.3365, Test Loss : 0.2066, Train Acc : 90.6250, Test Acc : 93.1500
# Iteration : 120 - Train Loss : 0.2643, Test Loss : 0.2382, Train Acc : 91.4062, Test Acc : 92.3100
# Iteration : 180 - Train Loss : 0.3286, Test Loss : 0.2089, Train Acc : 88.2812, Test Acc : 92.9500
# Iteration : 240 - Train Loss : 0.2982, Test Loss : 0.2259, Train Acc : 86.7188, Test Acc : 92.7200
# Iteration : 300 - Train Loss : 0.3161, Test Loss : 0.2312, Train Acc : 89.8438, Test Acc : 92.4800
# Iteration : 360 - Train Loss : 0.2861, Test Loss : 0.2048, Train Acc : 90.6250, Test Acc : 93.2900
# Epoch 121 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.2063, Test Loss : 0.1368, Train Acc : 92.1875, Test Acc : 95.4000
# Iteration : 120 - Train Loss : 0.1720, Test Loss : 0.1362, Train Acc : 93.7500, Test Acc : 95.3000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.3303, Test Loss : 0.1302, Train Acc : 89.8438, Test Acc : 95.4300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.2565, Test Loss : 0.1275, Train Acc : 89.8438, Test Acc : 95.7100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.2922, Test Loss : 0.1255, Train Acc : 88.2812, Test Acc : 95.8200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.2611, Test Loss : 0.1199, Train Acc : 89.8438, Test Acc : 96.0200
# Epoch 131 Started...
# Iteration : 60 - Train Loss : 0.1142, Test Loss : 0.1262, Train Acc : 97.6562, Test Acc : 95.9400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.0720, Test Loss : 0.1260, Train Acc : 96.8750, Test Acc : 96.0700
# Iteration : 180 - Train Loss : 0.2387, Test Loss : 0.1199, Train Acc : 92.1875, Test Acc : 95.9900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.1652, Test Loss : 0.1214, Train Acc : 93.7500, Test Acc : 96.1400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.1340, Test Loss : 0.1233, Train Acc : 95.3125, Test Acc : 96.2200
# Iteration : 360 - Train Loss : 0.1105, Test Loss : 0.1211, Train Acc : 96.8750, Test Acc : 96.1200
# Epoch 141 Started...
# Iteration : 60 - Train Loss : 0.1186, Test Loss : 0.1262, Train Acc : 95.3125, Test Acc : 96.1100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.1176, Test Loss : 0.1173, Train Acc : 95.3125, Test Acc : 96.4100
# Iteration : 180 - Train Loss : 0.1364, Test Loss : 0.1193, Train Acc : 95.3125, Test Acc : 96.2600
# Iteration : 240 - Train Loss : 0.1486, Test Loss : 0.1162, Train Acc : 96.0938, Test Acc : 96.2800
# Iteration : 300 - Train Loss : 0.1677, Test Loss : 0.1256, Train Acc : 93.7500, Test Acc : 96.3000
# Iteration : 360 - Train Loss : 0.1445, Test Loss : 0.1211, Train Acc : 95.3125, Test Acc : 96.3200
# Epoch 151 Started...
# Iteration : 60 - Train Loss : 0.1088, Test Loss : 0.1299, Train Acc : 96.8750, Test Acc : 96.1800
# Iteration : 120 - Train Loss : 0.1333, Test Loss : 0.1277, Train Acc : 94.5312, Test Acc : 96.2200
# Iteration : 180 - Train Loss : 0.1573, Test Loss : 0.1295, Train Acc : 93.7500, Test Acc : 96.1000
# Iteration : 240 - Train Loss : 0.1880, Test Loss : 0.1272, Train Acc : 94.5312, Test Acc : 96.2900
# Iteration : 300 - Train Loss : 0.1932, Test Loss : 0.1281, Train Acc : 93.7500, Test Acc : 96.1400
# Iteration : 360 - Train Loss : 0.1273, Test Loss : 0.1298, Train Acc : 95.3125, Test Acc : 96.1600
# Epoch 161 Started...
# Iteration : 60 - Train Loss : 0.0706, Test Loss : 0.1204, Train Acc : 96.8750, Test Acc : 96.3600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.0935, Test Loss : 0.1169, Train Acc : 96.0938, Test Acc : 96.4700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.1376, Test Loss : 0.1164, Train Acc : 97.6562, Test Acc : 96.5100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.1174, Test Loss : 0.1197, Train Acc : 96.0938, Test Acc : 96.5400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.0862, Test Loss : 0.1169, Train Acc : 97.6562, Test Acc : 96.6000
# Iteration : 360 - Train Loss : 0.0873, Test Loss : 0.1128, Train Acc : 98.4375, Test Acc : 96.5100
# Epoch 171 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.1329, Test Loss : 0.1088, Train Acc : 95.3125, Test Acc : 96.7600
# Iteration : 120 - Train Loss : 0.1279, Test Loss : 0.1108, Train Acc : 94.5312, Test Acc : 96.5800
# Iteration : 180 - Train Loss : 0.0549, Test Loss : 0.1073, Train Acc : 97.6562, Test Acc : 96.7500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.0884, Test Loss : 0.1097, Train Acc : 97.6562, Test Acc : 96.8100
# Iteration : 300 - Train Loss : 0.0829, Test Loss : 0.1095, Train Acc : 98.4375, Test Acc : 96.7100
# Iteration : 360 - Train Loss : 0.0999, Test Loss : 0.1116, Train Acc : 94.5312, Test Acc : 96.6600
# Epoch 181 Started...
# Iteration : 60 - Train Loss : 0.0748, Test Loss : 0.1095, Train Acc : 96.8750, Test Acc : 96.6800
# Iteration : 120 - Train Loss : 0.0861, Test Loss : 0.1109, Train Acc : 97.6562, Test Acc : 96.6900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.0524, Test Loss : 0.1092, Train Acc : 98.4375, Test Acc : 96.8300
# Iteration : 240 - Train Loss : 0.0544, Test Loss : 0.1102, Train Acc : 97.6562, Test Acc : 96.7100
# Iteration : 300 - Train Loss : 0.0919, Test Loss : 0.1115, Train Acc : 96.0938, Test Acc : 96.6700
# Iteration : 360 - Train Loss : 0.0423, Test Loss : 0.1103, Train Acc : 99.2188, Test Acc : 96.7300
# Epoch 191 Started...
# Iteration : 60 - Train Loss : 0.0275, Test Loss : 0.1110, Train Acc : 99.2188, Test Acc : 96.7200
# Iteration : 120 - Train Loss : 0.1210, Test Loss : 0.1127, Train Acc : 95.3125, Test Acc : 96.6500
# Iteration : 180 - Train Loss : 0.1041, Test Loss : 0.1119, Train Acc : 95.3125, Test Acc : 96.6400
# Iteration : 240 - Train Loss : 0.0704, Test Loss : 0.1083, Train Acc : 96.8750, Test Acc : 96.7200
# Iteration : 300 - Train Loss : 0.0737, Test Loss : 0.1078, Train Acc : 98.4375, Test Acc : 96.6000
# Iteration : 360 - Train Loss : 0.0707, Test Loss : 0.1111, Train Acc : 98.4375, Test Acc : 96.7500
# Epoch 201 Started...
# Iteration : 60 - Train Loss : 0.0490, Test Loss : 0.1111, Train Acc : 97.6562, Test Acc : 96.7100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.0901, Test Loss : 0.1072, Train Acc : 96.0938, Test Acc : 96.8600
# Iteration : 180 - Train Loss : 0.1725, Test Loss : 0.1083, Train Acc : 94.5312, Test Acc : 96.8600
# Iteration : 240 - Train Loss : 0.0595, Test Loss : 0.1093, Train Acc : 97.6562, Test Acc : 96.8300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.1232, Test Loss : 0.1093, Train Acc : 96.8750, Test Acc : 96.8700
# Iteration : 360 - Train Loss : 0.0973, Test Loss : 0.1082, Train Acc : 98.4375, Test Acc : 96.8200

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(WRN_28_10.train_losses, label='Train')
test_lossline, = plt.plot(WRN_28_10.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(WRN_28_10.train_acc, label='Train')
test_accline, = plt.plot(WRN_28_10.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')
